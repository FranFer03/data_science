# %% [markdown]
# # **Practica Integradora**
# Este conjunto de datos proporcionado por una organización de aerolíneas, que llamaremos "Aerolíneas Invistico”, está compuesto por 23 columnas y 130 mil columnas.
# El conjunto de datos se compone de los datos de los clientes que ya han volado con ellos. Se han consolidado los comentarios de los clientes sobre diversos contextos y sus datos de vuelo.
#
# ### **Hipótesis:**
#
# El objetivo principal es predecir si un futuro cliente estará satisfecho con el servicio, utilizando datos de parámetros anteriores.
# Además, la aerolínea busca identificar áreas en las que deba enfocarse para mejorar y generar clientes más satisfechos.
#
# ### **Diccionario de datos**
#
# * satisfaction: Representa el nivel de satisfacción del cliente con su
# experiencia de vuelo en general. Es una variable categórica con dos posibles valores: "satisfied" o "dissatisfied".
#
# * Gender: Indica el género del cliente. Es una variable categórica con dos posibles valores: "Male" o "Female".
#
# * Customer Type: Categoriza a los clientes según su tipo. Es una variable categórica con dos posibles valores: "Loyal Customer" o "Disloyal Customer"
#
# * Age: Representa la edad del cliente. Es una variable numérica expresada en años.
#
# * Type of Travel: Indica el propósito del viaje del cliente. Es una variable categórica con dos posibles valores: "Business travel" o "Personal travel".
#
# * Class: representa la clase de servicio que el cliente eligió. Es una variable categórica con tres posibles valores: "Eco", "Eco Plus", o "Business"
#
# * Flight Distance: Esta columna denota la distancia del vuelo en millas. Es una variable numérica.
#
# * Seat comfort: Esta columna representa la satisfacción del cliente con la comodidad del asiento. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Departure/Arrival time convenient: Esta columna denota la
# satisfacción del cliente con la conveniencia de los horarios de salida y llegada. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Food and drink: Esta columna representa la satisfacción del cliente con la comida y bebida proporcionada durante el vuelo. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Gate location: Esta columna denota la satisfacción del cliente con la ubicación de la puerta de embarque. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Inflight wifi service: Esta columna representa la satisfacción del cliente con el servicio de wifi a bordo. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Inflight entertainment: Esta columna denota la satisfacción del cliente con las opciones de entretenimiento a bordo. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Online support: Esta columna representa la satisfacción del cliente con el soporte en línea. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Ease of Online booking: Esta columna denota la satisfacción del cliente con la facilidad de reserva en línea. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * On-board service: Esta columna representa la satisfacción del cliente con el servicio a bordo proporcionado por la aerolínea. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Leg room service: Esta columna denota la satisfacción del cliente con el espacio para las piernas proporcionado durante el vuelo. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Baggage handling: Esta columna representa la satisfacción del cliente con el manejo del equipaje por parte de la aerolínea. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Checkin service: Esta columna denota la satisfacción del cliente con el servicio de check-in de la aerolínea. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Cleanliness: Esta columna representa la satisfacción del cliente con la limpieza de la aeronave. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Online boarding: Esta columna denota la satisfacción del cliente con el proceso de embarque en línea. Es una variable numérica, medida en una escala de 0 a 5, donde valores más altos indican mayor satisfacción.
#
# * Departure Delay in Minutes: Esta columna representa la duración del retraso en la salida en minutos para cada vuelo. Es una variable numérica.
# * Arrival Delay in Minutes: Esta columna denota la duración del retraso en la llegada en minutos para cada vuelo. Es una variable numérica.

# %% [markdown]
# ### **Objetivo Analítico:**
#
# Predecir la satisfacción del cliente ("satisfaction") basándote en los datos disponibles.
#
# ### **Contexto Comercial**
#
# "Aerolíneas Invistico", una aerolínea que busca mejorar la satisfacción del cliente y, al mismo tiempo, identificar áreas de enfoque para lograrlo.
#
# ### **Problema Comercial**
#
# "Aerolíneas Invistico está buscando identificar factores clave que influyen en la satisfacción del cliente para tomar medidas que mejoren la experiencia del cliente y, como resultado, aumentar la retención de clientes y la lealtad a la marca."
#
# ### **Análisis Exploratorio de Datos (EDA)**
#
# **Carga y exploración de datos**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score,r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score

plt.style.use('ggplot')

# %%
data = pd.read_csv("Invistico_Airline.csv")

# %%
data.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %% [markdown]
# Verificamos primero los datos para saber si estos obtiene datos nulos

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# ...

# %% [markdown]
# Se pude comprobar que el dataset **no tiene datos nulos**. No sera necesario hacer una "cirujia" de los datos para arreglarlos.

# %% [markdown]
# # **Graficas y conclusiones**

# %% [markdown]
# ### **Regla de Sturges**
#
# Obtenemos el numero de intervalos

# %%
num_bins = np.int(np.log2(len(data))) + 1
# Out:
# <ipython-input-6-b770f8f79df9>:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   num_bins = np.int(np.log2(len(data))) + 1

# %%
fig,ax = plt.subplots(figsize = (7,5))
ax = sns.histplot(data = data["Age"],kde=True,bins = num_bins)
ax.set_ylabel("Pasajeros")
ax.set_xlabel("Edad")
ax.set_title("Histograma de la edad de los pasajeros")
# Out:
# Text(0.5, 1.0, 'Histograma de la edad de los pasajeros')

# %% [markdown]
# Se puede observar que usualmente son personas de entre 20 a 55 años quienes usualmente realizan vuelos con esta aerolinea.

# %% [markdown]
# Para realizar un grafico de pie se agrupan la cantidad los datos del tipo de consumir y luego la cantidad contada es almacenada en un campo llamado cantidad.

# %%
custumertype_bar = data.groupby("Customer Type").size().reset_index(name="cantidad")
custumertype_bar
# Out:
#        Customer Type  cantidad
# 0     Loyal Customer    106100
# 1  disloyal Customer     23780

# %%
fig,ax = plt.subplots(figsize = (7,5))
plt.pie(custumertype_bar["cantidad"], labels=custumertype_bar["Customer Type"], autopct='%.2f%%')
ax.set_title("Lealtad de los pasajeros")
# Out:
# Text(0.5, 1.0, 'Lealtad de los pasajeros')

# %% [markdown]
# Para realizar un grafico de barras se agrupan la cantidad los datos de satisfacción y luego la cantidad contada es almacenada en un campo llamado contador.

# %%
barplot_satisfaction = data.groupby("satisfaction").size().reset_index(name="contador")
barplot_satisfaction
# Out:
#    satisfaction  contador
# 0  dissatisfied     58793
# 1     satisfied     71087

# %%
fig,ax = plt.subplots(figsize = (6,5))
ax.bar(barplot_satisfaction["satisfaction"],
       barplot_satisfaction["contador"],color =["#2ab07e","#38578c"])
ax.set_ylabel("Pasajeros")
ax.set_title("Satisfacción de los pasajeros")
# Out:
# Text(0.5, 1.0, 'Satisfacción de los pasajeros')

# %%
scatter_distance = sns.scatterplot(data=data,y='Flight Distance', x='Departure Delay in Minutes',hue='satisfaction', alpha=0.5)
scatter_distance.set_title("Distancia vs Demora de partida")
# Out:
# Text(0.5, 1.0, 'Distancia vs Demora de partida')

# %% [markdown]
# El gráfico de dispersión muestra un patrón interesante: cuando los vuelos son más cortos (1200 Km), es poco común encontrar demoras o, si las hay, son generalmente mínimas en comparación con los vuelos de mayor distancia. Sin embargo, lo que resulta particularmente notable es que, en vuelos de mayor distancia, incluso si la duración del retraso es la misma, una proporción significativamente mayor de pasajeros tiende a sentirse insatisfecha. Además, a medida que el retraso se incrementa en los vuelos de mayor distancia, también tiende a aumentar la insatisfacción entre los pasajeros. Esto sugiere que tanto la longitud del vuelo como la magnitud del retraso influyen en los niveles de satisfacción de los pasajeros.

# %% [markdown]
# Obtenemos una lista con las variables que fueron puntuadas. Es decir las variables **cualitativas ordinales**.

# %%
data.columns.tolist()
# Out:
# ['satisfaction',
#  'Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Seat comfort',
#  'Departure/Arrival time convenient',
#  'Food and drink',
#  'Gate location',
#  'Inflight wifi service',
#  'Inflight entertainment',
#  'Online support',
#  'Ease of Online booking',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Cleanliness',
#  'Online boarding',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes']

# %%
rating_columns = data.columns.tolist()
rating_columns = rating_columns[7:21]
print(rating_columns)
# Out:
# ['Seat comfort', 'Departure/Arrival time convenient', 'Food and drink', 'Gate location', 'Inflight wifi service', 'Inflight entertainment', 'Online support', 'Ease of Online booking', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding']

# %%
sns.set_style("darkgrid")
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(14, 14))
for i, feature in enumerate(rating_columns):
    row, col = divmod(i, 2)
    sns.barplot(x=feature, y="satisfaction", data=data, ax=axes[row, col],palette="viridis")
    axes[row, col].set_title(feature)
    axes[row, col].set_ylabel("Satisfaction")
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=7, figsize=(8, 29))
important_features = ["Inflight entertainment","Online support","Seat comfort","Ease of Online booking","On-board service", "Leg room service","Online boarding"]
i = 0
for feature in important_features:
  sns.countplot(x = feature, hue = 'satisfaction', data = data ,ax=axes[i],palette="viridis")
  i += 1

# %% [markdown]
# Observamos que el "Inflight entertainment" juega un papel fundamental en la satisfacción del cliente, ya que existe una diferencia significativa entre los niveles de satisfacción de los clientes satisfechos y los insatisfechos. En consecuencia, esta característica puede considerarse la más influyente.
#
# Además, características como la ""Seat comfort," "Online support," "Ease of Online booking," "On-board service,", "Leg room service" y "Online boarding" siguen de cerca al "Inflight entertainment" en términos de importancia.
#
# De esta forma nos permite realizar un filtro en las categorias. Reduciendo asi la cantidad variables cuando se realice el algoritmo de Clasificación.

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(6,4))
bar_class = sns.countplot(x="Class", data=data, hue="satisfaction", palette = "viridis", alpha=0.7 )
bar_class.set_title("Distribucion de las clases de los boletos")
bar_class.set_ylabel("Pasajeros")
# Out:
# Text(0, 0.5, 'Pasajeros')

# %% [markdown]
# Se observa que la mayoría de los vuelo son realizados en clase “Business” y además posee un mayor porcentaje de satisfacción que las restantes clases.
# En la clase Eco se puede notar una gran cantidad de cliente insatisfechos. Para este caso es necesario hacer un mayor análisis sobre las comodidades que se proveen en esta clase, de manera simular al cuadro anterior, pero con el filtro que sean solo vuelos de esta categoría. Para así determinar cuáles son los puntos por mejorar para aumentar la cantidad de cliente satisfechos.

# %%
fig,ax= plt.subplots(figsize = (5,7))
plt.boxplot(data["Flight Distance"])
ax.set_ylabel("Distancia de vuelo")
ax.set_title("Caja de las distancias de vuelo")
# Out:
# Text(0.5, 1.0, 'Caja de las distancias de vuelo')

# %% [markdown]
# La mediana de los vuelos se encuentra a los 2000 Km, la caja de encuentra entre los 2500 Km a 1500 Km. Se puede observar puntos outliers arriba de los 4200 Km

# %% [markdown]
# ## **Correlación apartir de variable dummies**
# Para realizar un heatmap primero voy a realizar varibles dummies apartir de las variables cualitativas ordinales y cardinales que no fueron utilizadas en el analisis anterior donde fueron usadas las variables de calificación de servicios.

# %%
data_featuredrop = data.drop(rating_columns,axis=1)

# %%
data2 = pd.get_dummies(data_featuredrop, columns=["Gender"], prefix=["Gender"])
data2 = pd.get_dummies(data2, columns=["Class"], prefix=["Class"])
data2 = pd.get_dummies(data2, columns=["Type of Travel"])
data2 = pd.get_dummies(data2, columns=["Customer Type"])
data2 = pd.get_dummies(data2, columns=["satisfaction"],prefix=["Customer"])
data2.head()
# Out:
#    Age  Flight Distance  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0   65              265                           0                       0.0
# 1   47             2464                         310                     305.0
# 2   15             2138                           0                       0.0
# 3   60              623                           0                       0.0
# 4   70              354                           0                       0.0
#
#    Gender_Female  Gender_Male  Class_Business  Class_Eco  Class_Eco Plus  \
# 0              1            0               0          1               0
# 1              0            1               1          0               0
# 2              1            0               0          1               0
# 3              1            0               0          1               0
# 4              1            0               0          1               0
#
# ...

# %% [markdown]
# ## **Reduccipon del dataset para los modelos de machine learning**

# %%
correlation_matrix = data2.corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Mapa de Calor de Correlación")
# Out:
# Text(0.5, 1.0, 'Mapa de Calor de Correlación')

# %% [markdown]
# Existe una correlación negativa moderada entre **"Age"** y **"Flight Distance"** (-0.25), lo que sugiere que a medida que la edad del cliente aumenta, la distancia de vuelo tiende a disminuir ligeramente.
#
# **"Departure Delay in Minutes"** y **"Arrival Delay in Minutes"** tienen una correlación fuerte positiva (0.97), lo que indica que los retrasos en la salida y la llegada están altamente correlacionados. Esta ultima no me parece una varible a considerar en el algoritmo de clasificacion.

# %% [markdown]
# ### Filtrados de feature
# Debido a que "Departure Delay in Minutes" y "Arrival Delay in Minutes" son correlacionadas porque ambas producen el mismo efecto

# %%
data = data.drop(columns=["Arrival Delay in Minutes"])
data.head(2)
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
#
#    Food and drink  ...  Inflight entertainment  Online support  \
# 0               0  ...                       4               2
# 1               0  ...                       2               2
#
#    Ease of Online booking  On-board service  Leg room service  \
# 0                       3                 3                 0
# 1                       3                 4                 4
#
#    Baggage handling  Checkin service  Cleanliness  Online boarding  \
# 0                 3                5            3                2
# ...

# %% [markdown]
# ## **Preparacion del dataset para los modelos de machine learning**

# %%
data = pd.read_csv("Invistico_Airline.csv")
X = data.drop(columns=["satisfaction","Arrival Delay in Minutes"])
Y = data["satisfaction"]

# %% [markdown]
# ### **Encondig**
#
# Realizamos encoding de las varibale cualitativas

# %%
# Label Encoding.
label_encoder = LabelEncoder()
for i in ['Gender', 'Customer Type', 'Type of Travel']:
    X[i] = label_encoder.fit_transform(X[i])

# One-Hot Encoding
# En este caso, es mejor utilizar One-Hot Encoding, ya que no hay un orden inherente entre las clases.
X = pd.get_dummies(X, columns=['Class'])

X.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Flight Distance  Seat comfort  \
# 0       0              0   65               1              265             0
# 1       1              0   47               1             2464             0
# 2       0              0   15               1             2138             0
# 3       0              0   60               1              623             0
# 4       0              0   70               1              354             0
#
#    Departure/Arrival time convenient  Food and drink  Gate location  \
# 0                                  0               0              2
# 1                                  0               0              3
# 2                                  0               0              3
# 3                                  0               0              3
# 4                                  0               0              3
#
#    Inflight wifi service  ...  On-board service  Leg room service  \
# ...

# %% [markdown]
# ## **Normalización**

# %%
std_scaled = StandardScaler()
features_to_scaler = ["Age", "Flight Distance", "Departure Delay in Minutes"]
features_scaled = std_scaled.fit_transform(X[features_to_scaler])
X[["Age", "Flight Distance", "Departure Delay in Minutes"]] = features_scaled
X.head()
# Out:
#    Gender  Customer Type       Age  Type of Travel  Flight Distance  \
# 0       0              0  1.691351               1        -1.671103
# 1       1              0  0.500820               1         0.469852
# 2       0              0 -1.615680               1         0.152458
# 3       0              0  1.360648               1        -1.322552
# 4       0              0  2.022054               1        -1.584452
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  Inflight wifi service  ...  On-board service  \
# 0              2                      2  ...                 3
# ...

# %% [markdown]
# División del dataset mediante la libreria Sckit learning

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ## **Modelado de algoritmos y Metricas**
# Debido a que estamos trabajando con una variable binaria categorica no ordinal (solo tiene 2 valores) "satisfaction" e "unsatisfaction".
# Decidimos trabajar con los siguientes algoritmos.
# * Logistic Regression
# * Decision Tree Classifier
# * Random Forest Classifier

# %%
model_Logistic = LogisticRegression(max_iter=2000)
model_Logistic.fit(X_train,y_train)
y_pred_Tree = model_Logistic.predict(X_test)
acc = accuracy_score(y_test, y_pred_Tree)

cross = cross_val_score(model_Logistic, X_train, y_train, cv=5)

pos_label = 'dissatisfied'
recall = recall_score(y_test, y_pred_Tree, pos_label=pos_label)

other_label = 'satisfied'
recall_other = recall_score(y_test, y_pred_Tree, pos_label=other_label)

print(f"Cross : {cross.mean():.3f} ")
print(f"Accuracy: {acc:.3f} Cross :{cross.mean():.3f} ")
print(f'Recall para {pos_label}: {recall:.3f}')
print(f'Recall para {other_label}: {recall_other:.3f}')
# Out:
# Cross : 0.835
# Accuracy: 0.834 Cross :0.835
# Recall para dissatisfied: 0.819
# Recall para satisfied: 0.847

# %%
model_Logistic = DecisionTreeClassifier()
model_Logistic.fit(X_train,y_train)
y_pred_Tree = model_Logistic.predict(X_test)
acc = accuracy_score(y_test, y_pred_Tree)

cross = cross_val_score(model_Logistic, X_train, y_train, cv=5)

pos_label = 'dissatisfied'
recall = recall_score(y_test, y_pred_Tree, pos_label=pos_label)

other_label = 'satisfied'
recall_other = recall_score(y_test, y_pred_Tree, pos_label=other_label)

print(f"Cross : {cross.mean():.3f} ")
print(f"Accuracy: {acc:.3f} Cross :{cross.mean():.3f} ")
print(f'Recall para {pos_label}: {recall:.3f}')
print(f'Recall para {other_label}: {recall_other:.3f}')
# Out:
# Cross : 0.937
# Accuracy: 0.942 Cross :0.937
# Recall para dissatisfied: 0.936
# Recall para satisfied: 0.946

# %%
model_Random_Forest = RandomForestClassifier()
model_Random_Forest.fit(X_train, y_train)
y_pred_Forest = model_Random_Forest.predict(X_test)
acc = accuracy_score(y_test, y_pred_Forest)
cross = cross_val_score(model_Random_Forest, X_train, y_train, cv=5)
pos_label = 'dissatisfied'
recall = recall_score(y_test, y_pred_Forest, pos_label=pos_label)
other_label = 'satisfied'
recall_other = recall_score(y_test, y_pred_Forest, pos_label=other_label)

print(f'Recall para {other_label}: {recall_other:.2f}')
print(f"Cross : {cross.mean():.3f} ")
print(f"Accuracy: {acc:.3f} Cross :{cross.mean():.3f} ")
print(f'Recall para {pos_label}: {recall:.3f}')
print(f'Recall para {other_label}: {recall_other:.3f}')
# Out:
# Recall para satisfied: 0.95
# Cross : 0.956
# Accuracy: 0.959 Cross :0.956
# Recall para dissatisfied: 0.966
# Recall para satisfied: 0.953

# %% [markdown]
# De a la metricas se puede comprobar que el **mejor modelo a utilizar es el Random Forest**

# %% [markdown]
# ## **Importancia de Features**
# El modelo seleccionado (Random Forest) perimite visualizar la importancia que tuvieron cada una de las features al momento del tomar la decisión

# %%
feature_importance = model_Random_Forest.feature_importances_
sorted_idx = np.argsort(feature_importance)
features = X.columns
plt.figure()
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), features[sorted_idx])
plt.xlabel('Feature Importance')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # Conclusión
#
# En base al análisis realizado, podemos concluir que la aerolínea "Invistico" debería enfocarse en mejorar los siguientes aspectos clave para satisfacer a sus pasajeros:
#
# * Sistema de Entretenimiento: Es importante invertir en la mejora del sistema de
# entretenimiento a bordo para hacer que los vuelos sean más agradables y atractivos para los pasajeros. Un sistema de entretenimiento de alta calidad puede marcar la diferencia en la experiencia del viaje.
#
# * Comodidad de los Asientos: La comodidad de los asientos es un factor fundamental para la satisfacción de los pasajeros.
#
# * Facilitar la Reserva en Línea: Asegurarse de que el proceso de reserva en línea sea intuitivo y eficiente. Esto incluye la navegación sencilla por el sitio web, la claridad en la presentación de opciones de vuelo, la disponibilidad de información sobre precios y políticas, y la facilidad para completar la reserva.
#
# * Mejorar el Soporte en Línea: Proporcionar un sólido sistema de soporte en línea para atender las necesidades de los pasajeros. Esto puede incluir chat en vivo, asistencia por correo electrónico y una sección de preguntas frecuentes bien organizada. Garantizar que los pasajeros puedan obtener respuestas a sus preguntas y resolver problemas de manera eficiente.
#
# El análisis también revela que la mayoría de los vuelos se realizan en edades comprendidas entre 25 y 55 años, y que las personas mayores tienden a preferir vuelos más cortos. Esta información puede ser útil para personalizar las ofertas y servicios para diferentes segmentos de edad.
#
# En cuanto al algoritmo seleccionado para el modelo de clasificación de árboles aleatorios, se ha demostrado que es la opción más robusta para la predicción. Esto es fundamental para tomar decisiones informadas en la gestión de la aerolínea.
#
# Además, se identificó que se podría realizar un filtrado en la categoría de "clase eco plus" sin que afecte significativamente al modelo de predicción. Sin embargo, se optó por no realizar dicho filtrado, ya que los cambios resultantes serían imperceptibles para el modelo.
#
# En resumen, al enfocarse en los aspectos mencionados y aprovechar la información demográfica de los pasajeros, la aerolínea "Invistico" puede mejorar la satisfacción de sus clientes y tomar decisiones informadas para ofrecer un servicio de alta calidad.
